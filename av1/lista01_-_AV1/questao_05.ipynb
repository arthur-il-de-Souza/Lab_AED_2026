# %% [markdown]
# ### 5. Alguém é o dobro

# %% [markdown]
# #### a) Lista não ordenada

# %%
# lista
v = [9, 42, 21, 14, 25, 3, 19, 33, 45, 6]

# %%
dobro = 0
for i in range(0, len(v), 1): 
    for j in range(0, len(v), 1):
        if v[i]*2 == v[j]:
            print(f"O número {v[j]} é o dobro de {v[i]}")
            break
# Out:
# O número 42 é o dobro de 21
# O número 6 é o dobro de 3

# %% [markdown]
# #### b) Lista ordenada

# %%
v.sort()

for i in range(0, len(v)-1, 1):
    for j in range(i, len(v), 1):
        cont+=1
        if v[i]*2 == v[j]:
            print(f"O número {v[j]} é o dobro de {v[i]}")
            break
        if v[i]*2 < v[j]: break
# Out:
# O número 6 é o dobro de 3
# O número 42 é o dobro de 21
