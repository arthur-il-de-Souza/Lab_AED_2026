# %% [markdown]
# ### 7. Contando inversões

# %%
# Listas
v = [9, 2, 7, 7, 2, 2, 1, 7, 7, 9]

# %%
inversao = 0
for i in range(0, len(v)-1, 1):
    for j in range(i, len(v), 1):
        if -i < j and v[i]>v[j]: inversao+=1
print(inversao)
# Out:
# 17
