# %% [markdown]
# ### 8. Trabalhando com duas listas

# %%
u = [9, 42, 21, 14, 25, 3, 19, 33, 45, 6]
v = [2, 15, 19, 12, 33, 9, 17, 41, 54, 8]

for i in range(0, len(u), 1):
    for j in range(0, len(v), 1):
        if u[i] == v[j]:
            print(v[j])
            break
# Out:
# 9
# 19
# 33
