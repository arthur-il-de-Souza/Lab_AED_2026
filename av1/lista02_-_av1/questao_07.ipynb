# %% [markdown]
# ### 7. Repetidos próximos

# %%
# Lista
v = [2, 1, 9, 7, 6, 3, 9, 4, 2, 6, 1, 3]

# %%
k = 4
check = 0

for i in range(0, len(v), 1):
    if i+k < len(v):
        for j in range(0, k, 1):
            if v[i] == v[i+j+1]:
                print(v[i])
                check = 1
                break
        if check: break
# Out:
# 9
